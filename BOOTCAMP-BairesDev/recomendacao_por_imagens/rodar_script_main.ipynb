# %% [markdown]
# # USAR SOMENTE NO COLAB

# %%
from google.colab import drive
drive.mount('/content/drive')

# Inicia o colab no diretório do projeto
# %cd /content/drive/MyDrive/caminho/para/pasta/do/projeto/

# %%
# cria um apelido para o caminho do diretório do projeto, nesse caso /pasta_local
# !ln -s /content/drive/MyDrive/caminho/para/pasta/do/projeto /pasta_local

# exibe o conteúdo da pasta
# !ls /pasta_local/

# %% [markdown]
# # USAR VSCODE

# %%
# importa as funções do arquivo main.py
from constantes import PASTA_TREINO, PASTA_TESTE
from graficos import espacador
from recomendacao import recomendar_produtos_similares, exibir_recomendacoes
import main
import os
# Out:
# Nenhuma GPU detectada. Usando CPU.
#
#
# ######################################### Dados de Treino ##########################################
#
# Found 640 files belonging to 4 classes.
# Found 128 files belonging to 4 classes.
# Found 128 files belonging to 4 classes.
#
# ######################################### Dados de Treino ##########################################
#
#
# ################################# Sumário Modelo Base MobileNetV2 ##################################
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ entrada (InputLayer)                │ (None, 224, 224, 3)          │             0 │    -    │
# ...

# %%
# Exemplo de recomendação
imagem_consulta = "./teste/relogio_feminino/relogio_feminino_23.jpg"
produtos_similares = recomendar_produtos_similares(PASTA_TREINO, imagem_consulta, main.modelo_extrator, main.cache_caracteristicas)
espacador('Relógo Feminino', 160)
exibir_recomendacoes(imagem_consulta, produtos_similares)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# ####################################################################### Relógo Feminino ########################################################################

# %%
# Exemplo de recomendação
imagem_consulta = "./teste/mocassim_masculino/mocassim_masculino_64.jpg"
produtos_similares = recomendar_produtos_similares(PASTA_TREINO, imagem_consulta, main.modelo_extrator, main.cache_caracteristicas)
espacador('Mocassim Masculino', 160)
exibir_recomendacoes(imagem_consulta, produtos_similares)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
#
# ###################################################################### Mocassim Masculino ######################################################################

# %%
# Exemplo de recomendação
imagem_consulta = "./teste/scarpin/scarpin_46.jpg"
produtos_similares = recomendar_produtos_similares(PASTA_TREINO, imagem_consulta, main.modelo_extrator, main.cache_caracteristicas)
espacador('Scarpin', 160)
exibir_recomendacoes(imagem_consulta, produtos_similares)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# ########################################################################### Scarpin ############################################################################

# %%
# Exemplo de recomendação
imagem_consulta = "./teste/relogio_masculino/relogio_masculino_62.jpg"
produtos_similares = recomendar_produtos_similares(PASTA_TREINO, imagem_consulta, main.modelo_extrator, main.cache_caracteristicas)
espacador('Relógo Masculino', 160)
exibir_recomendacoes(imagem_consulta, produtos_similares)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# ####################################################################### Relógo Masculino #######################################################################

# %%
# Exemplo de recomendação para todas as imagens de teste.
for raiz, dirs, arquivos in os.walk(PASTA_TESTE):
    nome_pasta = os.path.basename(raiz).replace('_', ' ').title()
    espacador(nome_pasta, 160)
    for arquivo in arquivos:
        if arquivo.endswith('.jpg'):
            caminho_arquivo = os.path.join(raiz, arquivo)
            produtos_similares = recomendar_produtos_similares(PASTA_TREINO, caminho_arquivo, main.modelo_extrator, main.cache_caracteristicas)
            exibir_recomendacoes(caminho_arquivo, produtos_similares)

# %% [markdown]
# # Kbô!!!  :)

# %% [markdown]
# ---
